# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 13
#      11 import torch.utils.data as data
#      12 import torch.optim as optim
# ---> 13 import torchvision
#      14 from torchvision.datasets import MNIST
#      15 from torchvision import transforms
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/torchvision/__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~/miniconda3/envs/d2l/lib/python3.9/site-packages/torchvision/models/__init__.py:2
#       1 from .alexnet import *
# ----> 2 from .convnext import *
#       3 from .densenet import *
#       4 from .efficientnet import *
#
# ...
